# %%
import requests
import lxml.html as lh
import pandas as pd

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = requests.get(url)
doc = lh.fromstring(page.content)
tr_elements = doc.xpath('//tr')

# %%
[len(T) for T in tr_elements[:12]]
# Out:
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]

# %% [markdown]
# Each Row consists of 3 columns.

# %%
r_elements = doc.xpath('//tr')

col=[]
i=0
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print ('%d:"%s"'%(i,name))
    col.append((name,[]))
# Out:
# 1:"Postcode"
# 2:"Borough"
# 3:"Neighbourhood
# "

# %% [markdown]
# Creating A Pandas Data Frame

# %%
for j in range(1,len(tr_elements)):
    T=tr_elements[j]
    if len(T)!=3:
        break
    
    i=0
    for t in T.iterchildren():
        data=t.text_content() 
        if i>0:
            try:
                data=int(data)
            except:
                pass
        col[i][1].append(data)
        i+=1

# %%
Data={title:column for (title,column) in col}
df=pd.DataFrame(Data)

# %%
df.head()
# Out:
#   Postcode           Borough     Neighbourhood\n
# 0      M1A      Not assigned      Not assigned\n
# 1      M2A      Not assigned      Not assigned\n
# 2      M3A        North York         Parkwoods\n
# 3      M4A        North York  Victoria Village\n
# 4      M5A  Downtown Toronto      Harbourfront\n

# %% [markdown]
# Assigning names to columns

# %%
df.columns = ['Borough', 'Neighbourhood','Postcode']
cols = df.columns.tolist()

cols = cols[-1:] + cols[:-1]
df = df[cols]
df.head()
# Out:
#              Postcode Borough     Neighbourhood
# 0      Not assigned\n     M1A      Not assigned
# 1      Not assigned\n     M2A      Not assigned
# 2         Parkwoods\n     M3A        North York
# 3  Victoria Village\n     M4A        North York
# 4      Harbourfront\n     M5A  Downtown Toronto

# %% [markdown]
# Cleaning all the unneccesary strings in borough

# %%
df = df.replace('\n',' ', regex=True)
df.head()
# Out:
#             Postcode Borough     Neighbourhood
# 0      Not assigned      M1A      Not assigned
# 1      Not assigned      M2A      Not assigned
# 2         Parkwoods      M3A        North York
# 3  Victoria Village      M4A        North York
# 4      Harbourfront      M5A  Downtown Toronto

# %% [markdown]
# Dropping all cells with a borough that is Not assigned

# %%
df.drop(df.index[df['Borough'] == 'Not assigned'], inplace = True)
df = df.reset_index(drop=True)
df.head()
# Out:
#             Postcode Borough     Neighbourhood
# 0      Not assigned      M1A      Not assigned
# 1      Not assigned      M2A      Not assigned
# 2         Parkwoods      M3A        North York
# 3  Victoria Village      M4A        North York
# 4      Harbourfront      M5A  Downtown Toronto

# %% [markdown]
# Combining Neighbourhoods based on similar Postcode and Borough

# %%
df = df.groupby(['Postcode', 'Borough'])['Neighbourhood'].apply(','.join).reset_index()
df.columns = ['Postcode','Borough','Neighbourhood']
df.head(10)
# Out:
#             Postcode Borough     Neighbourhood
# 0          Adelaide      M5H  Downtown Toronto
# 1         Agincourt      M1S       Scarborough
# 2   Agincourt North      M1V       Scarborough
# 3    Albion Gardens      M9V         Etobicoke
# 4         Alderwood      M8W         Etobicoke
# 5    Bathurst Manor      M3H        North York
# 6     Bathurst Quay      M5V  Downtown Toronto
# 7   Bayview Village      M2K        North York
# 8  Beaumond Heights      M9V         Etobicoke
# 9      Bedford Park      M5M        North York

# %% [markdown]
# Remove unneccessary space/gaps in string

# %%
df['Neighbourhood'] = df['Neighbourhood'].str.strip()

# %% [markdown]
# Assigning Borough values to the Neignbourhood if is "Not assigned"

# %%
df.loc[df['Neighbourhood'] == 'Not assigned', 'Neighbourhood'] = df['Borough']

# %%
df.shape
# Out:
# (287, 3)

# %%
df.head()
# Out:
#            Postcode Borough     Neighbourhood
# 0         Adelaide      M5H  Downtown Toronto
# 1        Agincourt      M1S       Scarborough
# 2  Agincourt North      M1V       Scarborough
# 3   Albion Gardens      M9V         Etobicoke
# 4        Alderwood      M8W         Etobicoke

# %%
df
# Out:
#                                               Postcode Borough  \
# 0                                            Adelaide      M5H
# 1                                           Agincourt      M1S
# 2                                     Agincourt North      M1V
# 3                                      Albion Gardens      M9V
# 4                                           Alderwood      M8W
# 5                                      Bathurst Manor      M3H
# 6                                       Bathurst Quay      M5V
# 7                                     Bayview Village      M2K
# 8                                    Beaumond Heights      M9V
# 9                                        Bedford Park      M5M
# 10                                        Berczy Park      M5E
# 11                                        Birch Cliff      M1N
# 12                                  Bloordale Gardens      M9C
# 13                                           Brockton      M6K
# 14   Business Reply Mail Processing Centre 969 East...     M7Y
# 15                                        CFB Toronto      M3K
# 16                                           CN Tower      M5V
# 17                                        Cabbagetown      M4X
# 18                                Caledonia-Fairbanks      M6E
# 19              Canada Post Gateway Processing Centre      M7R
# 20                                          Cedarbrae      M1H
# 21                                 Central Bay Street      M5G
# 22                                          Chinatown      M5T
# 23                                           Christie      M6G
# 24                               Church and Wellesley      M4Y
# 25                                           Clairlea      M1L
# 26                                     Clarks Corners      M1T
# 27                                         Cliffcrest      M1M
# 28                                          Cliffside      M1M
# 29                                     Cliffside West      M1N
# ..                                                 ...     ...
# 257                                The Queensway West      M8Z
# 258                                       Thistletown      M9V
# 259                                  Thorncliffe Park      M4H
# 260                           Toronto Dominion Centre      M5K
# 261                                   Toronto Islands      M5J
# 262                                           Trinity      M6J
# 263                                  Underground city      M5X
# 264                                     Union Station      M5J
# 265                             University of Toronto      M5S
# 266                                       Upper Rouge      M1X
# 267                                       Upwood Park      M6L
# 268                                    Victoria Hotel      M5L
# 269                                  Victoria Village      M4A
# 270                                   West Deane Park      M9B
# 271                                         West Hill      M1E
# 272                                         Westmount      M9P
# 273                                            Weston      M9N
# 274                                           Wexford      M1R
# 275                                   Wexford Heights      M1P
# 276                                        Willowdale      M2M
# 277                                  Willowdale South      M2N
# 278                                   Willowdale West      M2R
# 279                                    Wilson Heights      M3H
# 280                                            Woburn      M1G
# 281                                  Woodbine Gardens      M4B
# 282                                  Woodbine Heights      M4C
# 283                                        York Mills      M2L
# 284                                   York Mills West      M2P
# 285                                   York University      M3J
# 286                                         Yorkville      M5R
#
#         Neighbourhood
# 0    Downtown Toronto
# 1         Scarborough
# 2         Scarborough
# 3           Etobicoke
# 4           Etobicoke
# 5          North York
# 6    Downtown Toronto
# 7          North York
# 8           Etobicoke
# 9          North York
# 10   Downtown Toronto
# 11        Scarborough
# 12          Etobicoke
# 13       West Toronto
# 14       East Toronto
# 15         North York
# 16   Downtown Toronto
# 17   Downtown Toronto
# 18               York
# 19        Mississauga
# 20        Scarborough
# 21   Downtown Toronto
# 22   Downtown Toronto
# 23   Downtown Toronto
# 24   Downtown Toronto
# 25        Scarborough
# 26        Scarborough
# 27        Scarborough
# 28        Scarborough
# 29        Scarborough
# ..                ...
# 257         Etobicoke
# 258         Etobicoke
# 259         East York
# 260  Downtown Toronto
# 261  Downtown Toronto
# 262      West Toronto
# 263  Downtown Toronto
# 264  Downtown Toronto
# 265  Downtown Toronto
# 266       Scarborough
# 267        North York
# 268  Downtown Toronto
# 269        North York
# 270         Etobicoke
# 271       Scarborough
# 272         Etobicoke
# 273              York
# 274       Scarborough
# 275       Scarborough
# 276        North York
# 277        North York
# 278        North York
# 279        North York
# 280       Scarborough
# 281         East York
# 282         East York
# 283        North York
# 284        North York
# 285        North York
# 286   Central Toronto
#
# [287 rows x 3 columns]

# %%
import pandas as pd 
import numpy as np 

link = "http://cocl.us/Geospatial_data"
df1 = pd.read_csv(link)

df1.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df1.shape
# Out:
# (103, 3)

# %% [markdown]
# Changing the column name Postal code to Postcode to merge the two data frames together

# %%
df1.columns = ['Postcode','Latitude','Longitude']
cols = df1.columns.tolist()

# %%
df.head()
# Out:
#            Postcode Borough     Neighbourhood
# 0         Adelaide      M5H  Downtown Toronto
# 1        Agincourt      M1S       Scarborough
# 2  Agincourt North      M1V       Scarborough
# 3   Albion Gardens      M9V         Etobicoke
# 4        Alderwood      M8W         Etobicoke

# %%
df.set_index('Postcode')
# Out:
#                                                    Borough     Neighbourhood
# Postcode
# Adelaide                                               M5H  Downtown Toronto
# Agincourt                                              M1S       Scarborough
# Agincourt North                                        M1V       Scarborough
# Albion Gardens                                         M9V         Etobicoke
# Alderwood                                              M8W         Etobicoke
# Bathurst Manor                                         M3H        North York
# Bathurst Quay                                          M5V  Downtown Toronto
# Bayview Village                                        M2K        North York
# Beaumond Heights                                       M9V         Etobicoke
# Bedford Park                                           M5M        North York
# Berczy Park                                            M5E  Downtown Toronto
# Birch Cliff                                            M1N       Scarborough
# Bloordale Gardens                                      M9C         Etobicoke
# Brockton                                               M6K      West Toronto
# Business Reply Mail Processing Centre 969 Eastern      M7Y      East Toronto
# CFB Toronto                                            M3K        North York
# CN Tower                                               M5V  Downtown Toronto
# Cabbagetown                                            M4X  Downtown Toronto
# Caledonia-Fairbanks                                    M6E              York
# Canada Post Gateway Processing Centre                  M7R       Mississauga
# Cedarbrae                                              M1H       Scarborough
# Central Bay Street                                     M5G  Downtown Toronto
# Chinatown                                              M5T  Downtown Toronto
# Christie                                               M6G  Downtown Toronto
# Church and Wellesley                                   M4Y  Downtown Toronto
# Clairlea                                               M1L       Scarborough
# Clarks Corners                                         M1T       Scarborough
# Cliffcrest                                             M1M       Scarborough
# Cliffside                                              M1M       Scarborough
# Cliffside West                                         M1N       Scarborough
# ...                                                    ...               ...
# The Queensway West                                     M8Z         Etobicoke
# Thistletown                                            M9V         Etobicoke
# Thorncliffe Park                                       M4H         East York
# Toronto Dominion Centre                                M5K  Downtown Toronto
# Toronto Islands                                        M5J  Downtown Toronto
# Trinity                                                M6J      West Toronto
# Underground city                                       M5X  Downtown Toronto
# Union Station                                          M5J  Downtown Toronto
# University of Toronto                                  M5S  Downtown Toronto
# Upper Rouge                                            M1X       Scarborough
# Upwood Park                                            M6L        North York
# Victoria Hotel                                         M5L  Downtown Toronto
# Victoria Village                                       M4A        North York
# West Deane Park                                        M9B         Etobicoke
# West Hill                                              M1E       Scarborough
# Westmount                                              M9P         Etobicoke
# Weston                                                 M9N              York
# Wexford                                                M1R       Scarborough
# Wexford Heights                                        M1P       Scarborough
# Willowdale                                             M2M        North York
# Willowdale South                                       M2N        North York
# Willowdale West                                        M2R        North York
# Wilson Heights                                         M3H        North York
# Woburn                                                 M1G       Scarborough
# Woodbine Gardens                                       M4B         East York
# Woodbine Heights                                       M4C         East York
# York Mills                                             M2L        North York
# York Mills West                                        M2P        North York
# York University                                        M3J        North York
# Yorkville                                              M5R   Central Toronto
#
# [287 rows x 2 columns]

# %%
df1.set_index('Postcode')
# Out:
#            Latitude  Longitude
# Postcode
# M1B       43.806686 -79.194353
# M1C       43.784535 -79.160497
# M1E       43.763573 -79.188711
# M1G       43.770992 -79.216917
# M1H       43.773136 -79.239476
# M1J       43.744734 -79.239476
# M1K       43.727929 -79.262029
# M1L       43.711112 -79.284577
# M1M       43.716316 -79.239476
# M1N       43.692657 -79.264848
# M1P       43.757410 -79.273304
# M1R       43.750072 -79.295849
# M1S       43.794200 -79.262029
# M1T       43.781638 -79.304302
# M1V       43.815252 -79.284577
# M1W       43.799525 -79.318389
# M1X       43.836125 -79.205636
# M2H       43.803762 -79.363452
# M2J       43.778517 -79.346556
# M2K       43.786947 -79.385975
# M2L       43.757490 -79.374714
# M2M       43.789053 -79.408493
# M2N       43.770120 -79.408493
# M2P       43.752758 -79.400049
# M2R       43.782736 -79.442259
# M3A       43.753259 -79.329656
# M3B       43.745906 -79.352188
# M3C       43.725900 -79.340923
# M3H       43.754328 -79.442259
# M3J       43.767980 -79.487262
# ...             ...        ...
# M6C       43.693781 -79.428191
# M6E       43.689026 -79.453512
# M6G       43.669542 -79.422564
# M6H       43.669005 -79.442259
# M6J       43.647927 -79.419750
# M6K       43.636847 -79.428191
# M6L       43.713756 -79.490074
# M6M       43.691116 -79.476013
# M6N       43.673185 -79.487262
# M6P       43.661608 -79.464763
# M6R       43.648960 -79.456325
# M6S       43.651571 -79.484450
# M7A       43.662301 -79.389494
# M7R       43.636966 -79.615819
# M7Y       43.662744 -79.321558
# M8V       43.605647 -79.501321
# M8W       43.602414 -79.543484
# M8X       43.653654 -79.506944
# M8Y       43.636258 -79.498509
# M8Z       43.628841 -79.520999
# M9A       43.667856 -79.532242
# M9B       43.650943 -79.554724
# M9C       43.643515 -79.577201
# M9L       43.756303 -79.565963
# M9M       43.724766 -79.532242
# M9N       43.706876 -79.518188
# M9P       43.696319 -79.532242
# M9R       43.688905 -79.554724
# M9V       43.739416 -79.588437
# M9W       43.706748 -79.594054
#
# [103 rows x 2 columns]

# %%
df_new = pd.merge(df, df1, on='Postcode')
df_new.head()
# Out:
# Empty DataFrame
# Columns: [Postcode, Borough, Neighbourhood, Latitude, Longitude]
# Index: []
